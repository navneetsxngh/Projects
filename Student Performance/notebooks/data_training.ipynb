# %%
import os
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
BASE_DIR = os.getcwd()
PROJECT_ROOT = os.path.dirname(BASE_DIR)
DATA_PATH = os.path.join(PROJECT_ROOT, "data", "preprocessed.csv")

# %%
df = pd.read_csv(DATA_PATH)
df.head()
# Out:
#    student_id  age  gender  academic_level  study_hours  self_study_hours  \
# 0           1   18       2               0         7.64              1.56
# 1           2   18       2               0         2.21              2.22
# 2           3   22       1               0         3.45              0.00
# 3           4   17       2               0         5.75              2.08
# 4           5   19       2               0         6.83              1.72
#
#    online_classes_hours  social_media_hours  gaming_hours  sleep_hours  ...  \
# 0                  2.20                3.05          2.19         6.52  ...
# 1                  2.10                1.65          2.55         5.97  ...
# 2                  0.29                1.34          2.08         8.39  ...
# 3                  3.01                2.27          2.20         6.31  ...
# 4                  3.33                2.65          0.70         8.01  ...
#
#    exercise_minutes  caffeine_intake_mg  part_time_job  upcoming_deadline  \
# 0                81                  38              1                  0
# 1               111                 339              0                  0
# 2                68                 266              0                  1
# 3               113                 480              1                  1
# 4               121                  24              1                  0
#
#    internet_quality  mental_health_score  focus_index  burnout_level  \
# 0                 1                   10        43.05          31.77
# 1                 1                    3        15.92          37.00
# 2                 1                    8        27.39          34.37
# 3                 2                    3        22.31          77.31
# 4                 1                    8        38.11          39.53
#
#    productivity_score  exam_score
# 0               73.65       50.16
# 1               13.70        1.00
# 2               45.15       18.30
# 3               20.92        9.37
# 4               59.23       27.81
#
# [5 rows x 21 columns]

# %%
from sklearn.model_selection import train_test_split
x = df.drop(columns = ['exam_score',])
y = df[['exam_score']]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 42)
print(f"Shape: x_train{x_train.shape}, x_test{x_test.shape}, y_train{y_train.shape}, y_test{y_test.shape}")
# Out:
# Shape: x_train(3750, 20), x_test(1250, 20), y_train(3750, 1), y_test(1250, 1)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

## Create a function to evaluate Model
def evaluate_model(true, predicted):
    mse = mean_squared_error(true, predicted)
    mae = mean_absolute_error(true, predicted)
    rmse = np.sqrt(mse)
    r2_square = r2_score(true, predicted)
    return mae, rmse, r2_square, mse

# %%
models = {
    "Random Forest" : RandomForestRegressor(),
    "Decision Tree" : DecisionTreeRegressor(),
    "Linear Regression" : LinearRegression(),
    "Ridge" : Ridge(),
    "Lasso" : Lasso(),
    "K-Neighbours Regressor" : KNeighborsRegressor(),
    "AdaBoost Regressor" : AdaBoostRegressor(),
    "Gradient Boost" : GradientBoostingRegressor(),
    "XGBoost" : XGBRegressor()
}

for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(x_train, y_train)

    ## Make Prediction
    y_train_pred = model.predict(x_train)
    y_test_pred = model.predict(x_test)

    ## Evaluate Train and Test Dataset
    model_train_mae, model_train_rmse, model_train_r2, model_train_mse = evaluate_model(y_train, y_train_pred)
    model_test_mae, model_test_rmse, model_test_r2, model_test_mse = evaluate_model(y_test, y_test_pred)

    print(list(models.keys())[i])

    print("Model Perfromance for Training Set")
    print("- Root mean Squared Error : {:.4f}".format(model_train_rmse))
    print("- Mean Absolute Error : {:.4f}".format(model_train_mae))
    print("- R-Squared : {:.4f}".format(model_train_r2))
    print("- Mean Squared Error : {:.4f}".format(model_train_mse))

    print("---------------------------------------------------------------")

    print("Model Perfromance for Test Set")
    print("- Root mean Squared Error : {:.4f}".format(model_test_rmse))
    print("- Mean Absolute Error : {:.4f}".format(model_test_mae))
    print("- R-Squared : {:.4f}".format(model_test_r2))
    print("- Mean Squared Error : {:.4f}".format(model_test_mse))

    print('=' * 35)
    print("\n")
# Out:
# Random Forest
# Model Perfromance for Training Set
# - Root mean Squared Error : 1.8450
# - Mean Absolute Error : 1.4415
# - R-Squared : 0.9773
# - Mean Squared Error : 3.4039
# ---------------------------------------------------------------
# Model Perfromance for Test Set
# - Root mean Squared Error : 5.0910
# - Mean Absolute Error : 3.9904
# - R-Squared : 0.8137
# - Mean Squared Error : 25.9182
# ===================================
#
#
# Decision Tree
# Model Perfromance for Training Set
# - Root mean Squared Error : 0.0000
# - Mean Absolute Error : 0.0000
# - R-Squared : 1.0000
# - Mean Squared Error : 0.0000
# ---------------------------------------------------------------
# Model Perfromance for Test Set
# - Root mean Squared Error : 7.1395
# - Mean Absolute Error : 5.5431
# - R-Squared : 0.6336
# - Mean Squared Error : 50.9724
# ===================================
#
#
# Linear Regression
# Model Perfromance for Training Set
# - Root mean Squared Error : 4.9018
# - Mean Absolute Error : 3.9070
# - R-Squared : 0.8396
# - Mean Squared Error : 24.0272
# ---------------------------------------------------------------
# Model Perfromance for Test Set
# - Root mean Squared Error : 5.0392
# - Mean Absolute Error : 3.9813
# - R-Squared : 0.8175
# - Mean Squared Error : 25.3940
# ===================================
#
#
# Ridge
# Model Perfromance for Training Set
# - Root mean Squared Error : 4.9018
# - Mean Absolute Error : 3.9070
# - R-Squared : 0.8396
# - Mean Squared Error : 24.0272
# ---------------------------------------------------------------
# Model Perfromance for Test Set
# - Root mean Squared Error : 5.0392
# - Mean Absolute Error : 3.9813
# - R-Squared : 0.8175
# - Mean Squared Error : 25.3939
# ===================================
#
#
# Lasso
# Model Perfromance for Training Set
# - Root mean Squared Error : 4.9140
# - Mean Absolute Error : 3.9135
# - R-Squared : 0.8388
# - Mean Squared Error : 24.1474
# ---------------------------------------------------------------
# Model Perfromance for Test Set
# - Root mean Squared Error : 5.0229
# - Mean Absolute Error : 3.9617
# - R-Squared : 0.8187
# - Mean Squared Error : 25.2294
# ===================================
#
#
# K-Neighbours Regressor
# Model Perfromance for Training Set
# - Root mean Squared Error : 8.3172
# - Mean Absolute Error : 6.7221
# - R-Squared : 0.5381
# - Mean Squared Error : 69.1758
# ---------------------------------------------------------------
# Model Perfromance for Test Set
# - Root mean Squared Error : 10.3640
# - Mean Absolute Error : 8.4724
# - R-Squared : 0.2280
# - Mean Squared Error : 107.4128
# ===================================
#
#
# AdaBoost Regressor
# Model Perfromance for Training Set
# - Root mean Squared Error : 5.1669
# - Mean Absolute Error : 4.2635
# - R-Squared : 0.8217
# - Mean Squared Error : 26.6967
# ---------------------------------------------------------------
# Model Perfromance for Test Set
# - Root mean Squared Error : 5.4999
# - Mean Absolute Error : 4.4703
# - R-Squared : 0.7826
# - Mean Squared Error : 30.2486
# ===================================
#
#
# Gradient Boost
# Model Perfromance for Training Set
# - Root mean Squared Error : 4.3054
# - Mean Absolute Error : 3.3738
# - R-Squared : 0.8762
# - Mean Squared Error : 18.5363
# ---------------------------------------------------------------
# Model Perfromance for Test Set
# - Root mean Squared Error : 5.0124
# - Mean Absolute Error : 3.9191
# - R-Squared : 0.8194
# - Mean Squared Error : 25.1245
# ===================================
#
#
# XGBoost
# Model Perfromance for Training Set
# - Root mean Squared Error : 1.1003
# - Mean Absolute Error : 0.7976
# - R-Squared : 0.9919
# - Mean Squared Error : 1.2107
# ---------------------------------------------------------------
# Model Perfromance for Test Set
# - Root mean Squared Error : 5.4501
# - Mean Absolute Error : 4.3373
# - R-Squared : 0.7865
# - Mean Squared Error : 29.7032
# ===================================
